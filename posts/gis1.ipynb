# %% [markdown]
# # Final Project Proposal

# %%
import pandas as pd 
import matplotlib as plt

# %%
df = pd.read_json("https://opendata.miamidade.gov/resource/rbng-6mha.json")
df.head(1400)
# Out:
#      :@computed_region_9gk8_96b4  :@computed_region_engu_ybxz  \
# 0                        26106.0                          NaN
# 1                        25182.0                          NaN
# 2                        26108.0                          NaN
# 3                        25184.0                          NaN
# 4                        25495.0                          NaN
# 5                        25493.0                          NaN
# 6                        25492.0                          NaN
# 7                        25493.0                          NaN
# 8                        25494.0                          NaN
# 9                        25488.0                          NaN
# 10                       25488.0                          NaN
# 11                       15538.0                          NaN
# 12                       24835.0                          NaN
# 13                       24835.0                          NaN
# ...

# %%
count_row = df.shape[0]  # gives number of row count
print(count_row)
# Out:
# 1000
